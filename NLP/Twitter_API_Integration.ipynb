# %% [markdown]
# ## 1. Installation & Configuration

# %%
import pandas as pd
import torch
import torch.nn.functional as F
from transformers import AutoTokenizer, AutoModelForSequenceClassification
import snscrape.modules.twitter as sntwitter
from datetime import datetime, timedelta
import warnings
warnings.filterwarnings('ignore')

print("✓ Bibliothèques chargées")
# Out:
# ✓ Bibliothèques chargées

# %%
import os
from dotenv import load_dotenv
from pathlib import Path
load_dotenv(Path(".env"))

# Device (CPU ou GPU)
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
print(f"Device: {device}")
# Out:
# Device: cpu

# %% [markdown]
# ## 2. Chargement de votre modèle FinBERT

# %% [markdown]
# ## 3. Fonction de récupération des tweets

# %% [markdown]
# ## 4. Fonction d'analyse de sentiment

# %% [markdown]
# ## 5. Pipeline complet : Fetch Tweets + Analyze

# %% [markdown]
# ## 6. Exemples d'utilisation

# %% [markdown]
# ## 7. Export des résultats (pour intégration équipe)

# %% [markdown]
# ## 8. Fonction API-ready pour votre équipe (tweets)
